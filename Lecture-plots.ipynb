# %% [markdown]
# # Lecture plots
#
# The code that made the plots in the lecture today.
#
# Nicole Hartman
#
# 21 Jul 2024

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
sns.set_theme(style="ticks")

# %% [markdown]
# ## Exercise 0: Pattern matching

# %%
# %%bash
# mkdir figures

# %%
plt.plot(x,cos_x);
plt.plot(x,sin_x)
plt.plot(x,np.ones_like(x))
plt.plot(x,x)
plt.plot(x,x**2)

# %%
x = np.linspace(-np.pi,np.pi)

for i,(y,title) in enumerate([(np.sin(x),'$\sin(x)$'),(np.cos(x),'$\cos(x)$'),(np.ones_like(x),'$1$'),(x,'$x$'),(x**2,'$x^2$')]):
    plt.plot(x,y,label=title)
    
    plt.text(0,4,title,ha='center',fontsize=36)
    plt.xlabel('$x$',fontsize=20)
    plt.ylabel('$y$',fontsize=20)
    plt.xlim(-3,3)
    plt.ylim(-3,6)
    plt.savefig(f'figures/fig{i}.pdf')
    plt.show()

# %%
N = 100

xi = np.random.uniform(-np.pi,np.pi,N)
eps = np.random.randn(N,)
yi = xi+ xi**2 + 0.5*eps

# %%
plt.scatter(xi,yi,marker='x',color='crimson')
plt.plot(x,x**2)
plt.xlabel('$x$',fontsize=20)
plt.ylabel('$y$',fontsize=20)
plt.xlim(-3,3)
plt.ylim(-3,6)
# Out:
# (-3.0, 6.0)

# %%
# yi = 

# plt.scatter(xi,xi+xi**3,marker='x',color='crimson')
# plt.plot(x,x+x**3)
plt.plot(x,x**3-.3*x**4-2*np.sin(x),color='dodgerblue',lw=4)
plt.xlabel('$x$',fontsize=20)
plt.ylabel('$f(x)$',fontsize=20)
plt.xlim(-3,4)
plt.ylim(-3,6)

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Exercise 1
#
# Deriving Newton's law
